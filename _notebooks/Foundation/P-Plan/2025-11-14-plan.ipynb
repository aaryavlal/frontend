# %%
---
toc: true
layout: post
title: Planning for Digital Famine Reborn
description: Plan to setup modules while dealing with Digital Famine Reborn challenges.
permalink: /planipynb
breadcrumbs: true
---

# %% [markdown]
# <div style="background: linear-gradient(135deg, #0f172a 0%, #1e293b 50%, #334155 100%); padding: 50px; border-radius: 15px; color: #e2e8f0; margin-bottom: 40px; box-shadow: 0 10px 30px rgba(0,0,0,0.3); border: 2px solid #38bdf8;">
#   <h1 style="margin: 0; font-size: 3em; text-shadow: 2px 2px 4px rgba(0,0,0,0.5); color: #38bdf8;">⚡ The Main Objective</h1>
#   <p style="font-size: 1.5em; margin: 15px 0 0 0; color: #94a3b8; font-weight: 500;">Teach Big Idea 4, submodule 3</p>
# </div>
#
# <h2 style="color: #38bdf8; border-bottom: 4px solid #38bdf8; padding-bottom: 15px; font-size: 2.2em; text-shadow: 1px 1px 2px rgba(0,0,0,0.1);">🔧 Breakdown:</h2>
#
# <div style="background: linear-gradient(135deg, #1e293b 0%, #334155 100%); padding: 30px; border-radius: 12px; margin: 25px 0; border-left: 6px solid #38bdf8; box-shadow: 0 4px 15px rgba(0,0,0,0.2);">
#   <h3 style="color: #38bdf8; margin-top: 0; font-size: 1.8em; display: flex; align-items: center; gap: 10px;">
#     <span style="background: #38bdf8; color: #0f172a; padding: 5px 15px; border-radius: 8px; font-weight: bold;">1</span>
#     Module 1: Computing Models
#     <span style="color: #94a3b8; font-weight: normal; font-size: 0.75em; margin-left: auto;">(Dhyan)</span>
#   </h3>
#
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #38bdf8;">Sequential Computing:</strong> Instructions processed one at a time; total time = sum of all steps
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #38bdf8;">Parallel Computing:</strong> Multiple processors on one computer run tasks simultaneously
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #38bdf8;">Distributed Computing:</strong> Multiple separate devices/computers work together on the same problem
#   </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #1e293b 0%, #334155 100%); padding: 30px; border-radius: 12px; margin: 25px 0; border-left: 6px solid #22d3ee; box-shadow: 0 4px 15px rgba(0,0,0,0.2);">
#   <h3 style="color: #22d3ee; margin-top: 0; font-size: 1.8em; display: flex; align-items: center; gap: 10px;">
#     <span style="background: #22d3ee; color: #0f172a; padding: 5px 15px; border-radius: 8px; font-weight: bold;">2</span>
#     Module 2: Why Parallel/Distributed Computing?
#     <span style="color: #94a3b8; font-weight: normal; font-size: 0.75em; margin-left: auto;">(Lucas)</span>
#   </h3>
#
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #22d3ee;">⚠️ Hardware Limits:</strong> Single processors hit speed limits (overheating issues)
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #22d3ee;">💰 Efficiency:</strong> Parallel/distributed solutions save time and money
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #22d3ee;">📈 Scalability:</strong> Better scalability for handling increased workloads
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #22d3ee;">🚀 Capacity:</strong> Enables solving problems too large for single computers (storage/processing capacity)
#   </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #1e293b 0%, #334155 100%); padding: 30px; border-radius: 12px; margin: 25px 0; border-left: 6px solid #06b6d4; box-shadow: 0 4px 15px rgba(0,0,0,0.2);">
#   <h3 style="color: #06b6d4; margin-top: 0; font-size: 1.8em; display: flex; align-items: center; gap: 10px;">
#     <span style="background: #06b6d4; color: #0f172a; padding: 5px 15px; border-radius: 8px; font-weight: bold;">3</span>
#     Module 3: Key Requirements & Limitations
#     <span style="color: #94a3b8; font-weight: normal; font-size: 0.75em; margin-left: auto;">(Arnav)</span>
#   </h3>
#
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #06b6d4;">✅ Independence Required:</strong> Tasks must be independent to run in parallel (no dependencies between steps)
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #06b6d4;">⏱️ Sequential Bottleneck:</strong> Sequential portions must still run in order (e.g., setup, initialization, combining results)
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #06b6d4;">📉 Diminishing Returns:</strong> Sequential portions limit maximum speedup (diminishing returns with more processors)
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #06b6d4;">🔄 System Overhead:</strong> Overhead from communication, coordination, and synchronization
#   </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #1e293b 0%, #334155 100%); padding: 30px; border-radius: 12px; margin: 25px 0; border-left: 6px solid #0ea5e9; box-shadow: 0 4px 15px rgba(0,0,0,0.2);">
#   <h3 style="color: #0ea5e9; margin-top: 0; font-size: 1.8em; display: flex; align-items: center; gap: 10px;">
#     <span style="background: #0ea5e9; color: #0f172a; padding: 5px 15px; border-radius: 8px; font-weight: bold;">4</span>
#     Module 4: Execution Time Calculations
#     <span style="color: #94a3b8; font-weight: normal; font-size: 0.75em; margin-left: auto;">(Aaryav)</span>
#   </h3>
#
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #0ea5e9;">📊 Sequential Formula:</strong> Sequential time = sum of all step times
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #0ea5e9;">⚡ Parallel Formula:</strong> Parallel time = sequential portion time + longest parallel task time
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0; background: #0f172a; padding: 15px; border-radius: 8px; border-left: 4px solid #0ea5e9;">
#     <strong style="color: #0ea5e9;">💡 Example:</strong> Steps of 40s, 50s, 80s → Sequential = 170s; Parallel (2 processors) = 90s (one does 40+50, other does 80)
#   </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #1e293b 0%, #334155 100%); padding: 30px; border-radius: 12px; margin: 25px 0; border-left: 6px solid #3b82f6; box-shadow: 0 4px 15px rgba(0,0,0,0.2);">
#   <h3 style="color: #3b82f6; margin-top: 0; font-size: 1.8em; display: flex; align-items: center; gap: 10px;">
#     <span style="background: #3b82f6; color: #0f172a; padding: 5px 15px; border-radius: 8px; font-weight: bold;">5</span>
#     Module 5: Speedup Formula
#     <span style="color: #94a3b8; font-weight: normal; font-size: 0.75em; margin-left: auto;">(Tanay)</span>
#   </h3>
#
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #3b82f6;">🧮 Core Formula:</strong> Speedup = Sequential Time ÷ Parallel Time
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0; background: #0f172a; padding: 15px; border-radius: 8px; border-left: 4px solid #3b82f6;">
#     <strong style="color: #3b82f6;">📈 Example:</strong> 170s ÷ 90s = 1.88× speedup
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #3b82f6;">📏 Metric Purpose:</strong> Measures efficiency improvement from parallelization
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #3b82f6;">🔒 Constraint:</strong> Always limited by the sequential portion
#   </p>
# </div>
#
# <div style="background: linear-gradient(135deg, #1e293b 0%, #334155 100%); padding: 30px; border-radius: 12px; margin: 25px 0; border-left: 6px solid #60a5fa; box-shadow: 0 4px 15px rgba(0,0,0,0.2);">
#   <h3 style="color: #60a5fa; margin-top: 0; font-size: 1.8em; display: flex; align-items: center; gap: 10px;">
#     <span style="background: #60a5fa; color: #0f172a; padding: 5px 15px; border-radius: 8px; font-weight: bold;">6</span>
#     Module 6: Real-World Applications
#     <span style="color: #94a3b8; font-weight: normal; font-size: 0.75em; margin-left: auto;">(Rudra)</span>
#   </h3>
#
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #60a5fa;">🖥️ Multi-Core CPUs:</strong> Modern processors (4-24 cores) in laptops and phones
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #60a5fa;">🎮 Graphics Cards (GPUs):</strong> Thousands of cores for gaming and AI training
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #60a5fa;">🏢 Server Farms:</strong> Data centers with thousands of interconnected servers
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #60a5fa;">🔬 Supercomputers:</strong> World's fastest systems for scientific research (millions of cores)
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #60a5fa;">☁️ Cloud Infrastructure:</strong> Distributed hardware networks (AWS, Azure, Google Cloud)
#   </p>
#   <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#     <strong style="color: #60a5fa;">📱 Mobile SoCs:</strong> System-on-Chip designs with specialized parallel processors
#   </p>
# </div>
#
# <hr style="border: none; border-top: 3px solid #38bdf8; margin: 40px 0;">
#
# <div style="background: linear-gradient(135deg, #1e293b 0%, #334155 100%); padding: 35px; border-radius: 12px; margin: 30px 0; border: 3px solid #f59e0b; box-shadow: 0 8px 25px rgba(245, 158, 11, 0.3);">
#   <h2 style="color: #f59e0b; margin-top: 0; font-size: 2em; display: flex; align-items: center; gap: 10px;">
#     🔐 Community Room System
#   </h2>
#
#   <div style="background: #0f172a; padding: 25px; border-radius: 10px; margin: 20px 0; border-left: 4px solid #f59e0b;">
#     <h3 style="color: #fbbf24; margin-top: 0;">How It Works:</h3>
#
#     <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#       <strong style="color: #f59e0b;">1. Room Creation:</strong> Only website admins can create room codes
#     </p>
#
#     <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#       <strong style="color: #f59e0b;">2. Join Community:</strong> Students enter a room code to join their learning community
#     </p>
#
#     <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#       <strong style="color: #f59e0b;">3. Collaborative Progress:</strong> The CPU visualization updates as a <strong>community effort</strong>
#     </p>
#
#     <div style="background: #1e293b; padding: 20px; border-radius: 8px; margin: 20px 0; border: 2px solid #fbbf24;">
#       <p style="color: #fbbf24; font-weight: bold; margin: 0 0 15px 0; font-size: 1.2em;">📊 Progress Tracking:</p>
#       <ul style="color: #e2e8f0; line-height: 2; font-size: 1.05em; margin: 0; padding-left: 25px;">
#         <li>When <strong style="color: #38bdf8;">ALL students in the room</strong> complete Module 1 → Node 1 lights up ⚡</li>
#         <li>When <strong style="color: #22d3ee;">ALL students</strong> complete Module 2 → Node 2 lights up ⚡</li>
#         <li>When <strong style="color: #06b6d4;">ALL students</strong> complete Module 3 → Node 3 lights up ⚡</li>
#         <li>When <strong style="color: #0ea5e9;">ALL students</strong> complete Module 4 → Node 4 lights up ⚡</li>
#         <li>When <strong style="color: #3b82f6;">ALL students</strong> complete Module 5 → Node 5 lights up ⚡</li>
#         <li>When <strong style="color: #60a5fa;">ALL students</strong> complete Module 6 → Node 6 lights up ⚡</li>
#       </ul>
#     </div>
#
#     <p style="color: #e2e8f0; line-height: 1.8; font-size: 1.1em; margin: 15px 0;">
#       <strong style="color: #f59e0b;">4. System Completion:</strong> Once all 6 modules are complete (entire CPU is lit) → The room is automatically deleted
#     </p>
#
#     <div style="background: linear-gradient(90deg, #f59e0b 0%, #fbbf24 100%); padding: 20px; border-radius: 10px; margin-top: 20px; text-align: center;">
#       <p style="margin: 0; font-size: 1.2em; color: #0f172a; font-weight: bold;">
#         💡 Key Feature: Teamwork drives progress!
#       </p>
#       <p style="margin: 10px 0 0 0; font-size: 0.95em; color: #1e293b;">
#         Every student's completion helps light up the next node for the entire community
#       </p>
#     </div>
#   </div>
# </div>
#
# <hr style="border: none; border-top: 3px solid #38bdf8; margin: 40px 0;">
#
# <div style="background: linear-gradient(135deg, #0f172a 0%, #1e293b 50%, #334155 100%); padding: 50px; border-radius: 15px; color: #e2e8f0; margin: 40px 0; box-shadow: 0 15px 40px rgba(56, 189, 248, 0.3); border: 3px solid #38bdf8; position: relative; overflow: hidden;">
#
#   <!-- Animated background elements -->
#   <div style="position: absolute; top: 10px; right: 10px; font-size: 4em; opacity: 0.1;">⚡</div>
#   <div style="position: absolute; bottom: 10px; left: 10px; font-size: 4em; opacity: 0.1;">💻</div>
#
#   <h2 style="margin: 0 0 20px 0; font-size: 2.5em; text-shadow: 2px 2px 4px rgba(0,0,0,0.5); color: #38bdf8; text-align: center;">
#     🖥️ ACTIVATE THE CPU
#   </h2>
#
#   <p style="font-size: 1.3em; margin: 20px 0; color: #94a3b8; text-align: center; font-weight: 500;">
#     Power all <strong style="color: #38bdf8;">6 NODES</strong> to bring the system online!
#   </p>
#
#   <!-- Node Grid -->
#   <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 20px; margin: 30px 0; max-width: 600px; margin-left: auto; margin-right: auto;">
#
#     <div style="background: #1e293b; padding: 20px; border-radius: 10px; text-align: center; border: 2px solid #38bdf8; box-shadow: 0 0 20px rgba(56, 189, 248, 0.3);">
#       <div style="font-size: 2em; margin-bottom: 10px;">⚡</div>
#       <div style="color: #38bdf8; font-weight: bold;">NODE 1</div>
#       <div style="color: #94a3b8; font-size: 0.9em;">Dhyan</div>
#     </div>
#
#     <div style="background: #1e293b; padding: 20px; border-radius: 10px; text-align: center; border: 2px solid #22d3ee; box-shadow: 0 0 20px rgba(34, 211, 238, 0.3);">
#       <div style="font-size: 2em; margin-bottom: 10px;">⚡</div>
#       <div style="color: #22d3ee; font-weight: bold;">NODE 2</div>
#       <div style="color: #94a3b8; font-size: 0.9em;">Lucas</div>
#     </div>
#
#     <div style="background: #1e293b; padding: 20px; border-radius: 10px; text-align: center; border: 2px solid #06b6d4; box-shadow: 0 0 20px rgba(6, 182, 212, 0.3);">
#       <div style="font-size: 2em; margin-bottom: 10px;">⚡</div>
#       <div style="color: #06b6d4; font-weight: bold;">NODE 3</div>
#       <div style="color: #94a3b8; font-size: 0.9em;">Arnav</div>
#     </div>
#
#     <div style="background: #1e293b; padding: 20px; border-radius: 10px; text-align: center; border: 2px solid #0ea5e9; box-shadow: 0 0 20px rgba(14, 165, 233, 0.3);">
#       <div style="font-size: 2em; margin-bottom: 10px;">⚡</div>
#       <div style="color: #0ea5e9; font-weight: bold;">NODE 4</div>
#       <div style="color: #94a3b8; font-size: 0.9em;">Aaryav</div>
#     </div>
#
#     <div style="background: #1e293b; padding: 20px; border-radius: 10px; text-align: center; border: 2px solid #3b82f6; box-shadow: 0 0 20px rgba(59, 130, 246, 0.3);">
#       <div style="font-size: 2em; margin-bottom: 10px;">⚡</div>
#       <div style="color: #3b82f6; font-weight: bold;">NODE 5</div>
#       <div style="color: #94a3b8; font-size: 0.9em;">Tanay</div>
#     </div>
#
#     <div style="background: #1e293b; padding: 20px; border-radius: 10px; text-align: center; border: 2px solid #60a5fa; box-shadow: 0 0 20px rgba(96, 165, 250, 0.3);">
#       <div style="font-size: 2em; margin-bottom: 10px;">⚡</div>
#       <div style="color: #60a5fa; font-weight: bold;">NODE 6</div>
#       <div style="color: #94a3b8; font-size: 0.9em;">Rudra</div>
#     </div>
#
#   </div>
#
#   <div style="background: linear-gradient(90deg, #38bdf8 0%, #3b82f6 100%); padding: 25px; border-radius: 12px; margin-top: 30px; text-align: center; box-shadow: 0 8px 25px rgba(56, 189, 248, 0.4);">
#     <p style="margin: 0; font-size: 1.4em; color: #0f172a; font-weight: bold;">
#       🚀 SYSTEM STATUS: READY TO COMPUTE
#     </p>
#     <p style="margin: 10px 0 0 0; font-size: 1em; color: #1e293b;">
#       All modules powered • Parallel processing enabled • Maximum efficiency achieved
#     </p>
#   </div>
#
# </div>
