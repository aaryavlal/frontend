# %%
---
toc: true
layout: post
title: Planning for Digital Famine Reborn
description: Plan to setup modules while dealing with Digital Famine Reborn challenges.
permalink: /planipynb
breadcrumbs: true
---
